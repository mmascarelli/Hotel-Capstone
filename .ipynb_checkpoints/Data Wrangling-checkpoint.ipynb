# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', 500)

# %% [markdown]
# # 1) Load in the Data

# %%
h1 = pd.read_csv('/Users/matt/Desktop/Capstone 2/data/H1.csv')
h2 = pd.read_csv('/Users/matt/Desktop/Capstone 2/data/H2.csv')

# %%
display(h1.head())
print('Shape of Hotel 1 Data: ', h1.shape)
# Out:
#    IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0           0       342             2015             July
# 1           0       737             2015             July
# 2           0         7             2015             July
# 3           0        13             2015             July
# 4           0        14             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 2                     27                      1                     0
# 3                     27                      1                     0
# 4                     27                      1                     0
#
#    StaysInWeekNights  Adults  Children  Babies       Meal Country  \
# 0                  0       2         0       0  BB            PRT
# ...

# %%
display(h2.head())
print('Shape of Hotel 2 Data: ', h2.shape)
# Out:
#    IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0           0         6             2015             July
# 1           1        88             2015             July
# 2           1        65             2015             July
# 3           1        92             2015             July
# 4           1       100             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 2                     27                      1                     0
# 3                     27                      1                     2
# 4                     27                      2                     0
#
#    StaysInWeekNights  Adults  Children  Babies       Meal Country  \
# 0                  2       1       0.0       0  HB            PRT
# ...

# %% [markdown]
# # 2) Concatenate our Dataframes into One
# Since our two dataframes have the same exact columns, we can stack them by using the `pd.concat()` function. We will also add a `Hotel` column so that we can tell which hotel each observation is coming from

# %%
raw_df = pd.concat([h1,h2], keys=['h1','h2'], names=['Hotel', 'drop']).reset_index().drop('drop', axis=1)
df = raw_df.copy()
display(df.head())
print('Shape of Full Data: ',df.shape)
# Out:
#   Hotel  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0    h1           0       342             2015             July
# 1    h1           0       737             2015             July
# 2    h1           0         7             2015             July
# 3    h1           0        13             2015             July
# 4    h1           0        14             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 2                     27                      1                     0
# 3                     27                      1                     0
# 4                     27                      1                     0
#
#    StaysInWeekNights  Adults  Children  Babies       Meal Country  \
# 0                  0       2       0.0       0  BB            PRT
# ...

# %% [markdown]
# # 3) Column Information

# %% [markdown]
# * `Hotel`: Identifies which hotel the observations belongs to (h1:Resort Hotel, h2: City Hotel)
# * `IsCanceled`: Target Varible. Indicates if booking was canceled (1) or not (0)
# * `LeadTime` : Number of days that elapsed between the entering date of the booking and the arrival date
# * `ArrivalDateYear` : Year of arrival date
# * `ArrivalDateMonth` : Month of arrival date
# * `ArrivalDateWeekNumber` : Week of arrival date
# * `ArrivalDateDayOfMonth` : Day of month for arrival date
# * `StaysInWeekendNights` : Number of weekend nights for booking
# * `StaysInWeekNights` : Number of week nights for booking
# * `Adults`: Number of adults
# * `Children` : Number of children
# * `Babies` : Number of babies
# * `Meal` : Type of meal package
#     * Undefined/SC – no meal package;
#     * BB – Bed & Breakfast;
#     * HB – Half board (breakfast and one other meal – usually dinner);
#     * FB – Full board (breakfast, lunch and dinner)
# * `Country` : Country of origin. Categories are represented in the ISO 3155–3:2013 format
#     * i.e. 'IRL' is Ireland, 'ESP' is Spain, etc
# * `MarketSegment` : Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”
# * `DistributionChannel` : Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
# * `IsRepeatedGuest` : Value indicating if the booking name was from a repeated guest (1) or not (0)
# * `PreviousCancellations` : Number of previous bookings that were cancelled by the customer prior to the current booking
# * `PreviousBookingsNotCanceled` : Number of previous bookings not cancelled by the customer prior to the current booking
# * `ReservedRoomType` : Code of room type reserved. Code is presented instead of designation for anonymity reasons
# * `AssignedRoomType` : 	Code for the type of room assigned to the booking. Sometimes the assigned room type differs from the reserved room type due to hotel operation reasons (e.g. overbooking) or by customer request. Code is presented instead of designation for anonymity reasons
# * `BookingChanges` : Number of changes/amendments made to the booking from the moment the booking was entered until the moment of check-in or cancellation
# * `DepositType` : Indication on if the customer made a deposit to guarantee the booking. This variable can assume three categories:
#     * No Deposit – no deposit was made
#     * Non Refund – a deposit was made in the value of the total stay cost
#     * Refundable – a deposit was made with a value under the total cost of stay.
# * `Agent` : ID of the travel agency that made the booking
# * `Company` : ID of the company/entity that made the booking or responsible for paying the booking. ID is presented instead of designation for anonymity reasons
# * `DaysInWaitingList` : Number of days the booking was in the waiting list before it was confirmed to the customer
# * `CustomerType` : Type of booking, assuming one of four categories:
#     * Contract - when the booking has an allotment or other type of contract associated to it;
#     * Group – when the booking is associated to a group;
#     * Transient – when the booking is not part of a group or contract, and is not associated to other transient booking;
#     * Transient-party – when the booking is transient, but is associated to at least other transient booking
# * `ADR` : Average Daily Rate
# * `RequiredCarParkingSpaces` : Number of car parking spaces required by the customer
# * `TotalOfSpecialRequests` : Number of special requests made by the customer (e.g. twin bed or high floor)
# * `ReservationStatus` : Reservation last status, assuming one of three categories:
#     * Canceled – booking was canceled by the customer;
#     * Check-Out – customer has checked in but already departed;
#     * No-Show – customer did not check-in and did inform the hotel of the reason why
# * `ReservationStatusDate` : Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Hotel                        119390 non-null  object
#  1   IsCanceled                   119390 non-null  int64
#  2   LeadTime                     119390 non-null  int64
#  3   ArrivalDateYear              119390 non-null  int64
#  4   ArrivalDateMonth             119390 non-null  object
#  5   ArrivalDateWeekNumber        119390 non-null  int64
#  6   ArrivalDateDayOfMonth        119390 non-null  int64
#  7   StaysInWeekendNights         119390 non-null  int64
#  8   StaysInWeekNights            119390 non-null  int64
#  9   Adults                       119390 non-null  int64
#  10  Children                     119386 non-null  float64
#  11  Babies                       119390 non-null  int64
# ...

# %% [markdown]
# # 4) Missing Values

# %%
df.isna().sum()
# Out:
# Hotel                            0
# IsCanceled                       0
# LeadTime                         0
# ArrivalDateYear                  0
# ArrivalDateMonth                 0
# ArrivalDateWeekNumber            0
# ArrivalDateDayOfMonth            0
# StaysInWeekendNights             0
# StaysInWeekNights                0
# Adults                           0
# Children                         4
# Babies                           0
# Meal                             0
# Country                        488
# MarketSegment                    0
# DistributionChannel              0
# IsRepeatedGuest                  0
# PreviousCancellations            0
# PreviousBookingsNotCanceled      0
# ReservedRoomType                 0
# AssignedRoomType                 0
# BookingChanges                   0
# DepositType                      0
# Agent                            0
# Company                          0
# DaysInWaitingList                0
# CustomerType                     0
# ...

# %% [markdown]
# ## `Children`

# %%
# 92% of the bookings have 0 children
df['Children'].value_counts(normalize=True)
# Out:
# 0.0     0.928049
# 1.0     0.040717
# 2.0     0.030590
# 3.0     0.000637
# 10.0    0.000008
# Name: Children, dtype: float64

# %%
df[df['Children'].isna()]
# Out:
#       Hotel  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 40600    h2           1         2             2015           August
# 40667    h2           1         1             2015           August
# 40679    h2           1         1             2015           August
# 41160    h2           1         8             2015           August
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 40600                     32                      3                     1
# 40667                     32                      5                     0
# 40679                     32                      5                     0
# 41160                     33                     13                     2
#
#        StaysInWeekNights  Adults  Children  Babies       Meal Country  \
# 40600                  0       2       NaN       0  BB            PRT
# 40667                  2       2       NaN       0  BB            PRT
# ...

# %%
# We will replace the null values with 0
df['Children'] = df['Children'].fillna(0)

# %% [markdown]
# ## `Country`

# %%
print('Number of Unique Countries: ',df['Country'].nunique())
# Out:
# Number of Unique Countries:  177

# %%
# 40% of the bookings are coming from Portugal, so we could fill the missing values with PRT
df['Country'].value_counts(normalize=True).to_frame().head(10)
# Out:
#       Country
# PRT  0.408656
# GBR  0.102008
# FRA  0.087593
# ESP  0.072059
# DEU  0.061286
# ITA  0.031673
# IRL  0.028385
# BEL  0.019697
# BRA  0.018704
# NLD  0.017695

# %%
# For now we will replace the missing values with `unknown`
df['Country'] = df['Country'].fillna('unknown')

# %% [markdown]
# # 5) Duplicated Rows

# %%
# We have 31,994 duplicated rows
df.duplicated().sum()
# Out:
# 31994

# %%
# It seems that some bookings were filed more than once
df[df.duplicated(keep=False)].head(10)
# Out:
#     Hotel  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 4      h1           0        14             2015             July
# 5      h1           0        14             2015             July
# 21     h1           0        72             2015             July
# 22     h1           0        72             2015             July
# 39     h1           0        70             2015             July
# 43     h1           0        70             2015             July
# 132    h1           1         5             2015             July
# 138    h1           1         5             2015             July
# 198    h1           0         0             2015             July
# 200    h1           0         0             2015             July
#
#      ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 4                       27                      1                     0
# 5                       27                      1                     0
# ...

# %%
# We will drop the duplicated rows, keeping the first of the duplicates. This leaves us with 87,396 rows
df = df.drop_duplicates(keep='first').reset_index(drop=True)

# %% [markdown]
# # 6) Exploring Columns Further

# %%
df.describe().T
# Out:
#                                count         mean        std      min     25%  \
# IsCanceled                   87396.0     0.274898   0.446466     0.00     0.0
# LeadTime                     87396.0    79.891368  86.052325     0.00    11.0
# ArrivalDateYear              87396.0  2016.210296   0.686102  2015.00  2016.0
# ArrivalDateWeekNumber        87396.0    26.838334  13.674572     1.00    16.0
# ArrivalDateDayOfMonth        87396.0    15.815541   8.835146     1.00     8.0
# StaysInWeekendNights         87396.0     1.005263   1.031921     0.00     0.0
# StaysInWeekNights            87396.0     2.625395   2.053584     0.00     1.0
# Adults                       87396.0     1.875795   0.626500     0.00     2.0
# Children                     87396.0     0.138633   0.455871     0.00     0.0
# Babies                       87396.0     0.010824   0.113597     0.00     0.0
# IsRepeatedGuest              87396.0     0.039075   0.193775     0.00     0.0
# ...

# %%
df.describe(include='object').T
# Out:
#                        count unique               top   freq
# Hotel                  87396      2                h2  53428
# ArrivalDateMonth       87396     12            August  11257
# Meal                   87396      5         BB         67978
# Country                87396    178               PRT  27453
# MarketSegment          87396      8         Online TA  51618
# DistributionChannel    87396      5             TA/TO  69141
# ReservedRoomType       87396     10  A                 56552
# AssignedRoomType       87396     12  A                 46313
# DepositType            87396      3   No Deposit       86251
# Agent                  87396    334                 9  28759
# Company                87396    353              NULL  82137
# CustomerType           87396      4         Transient  71986
# ReservationStatus      87396      3         Check-Out  63371
# ReservationStatusDate  87396    926        2016-02-14    211

# %% [markdown]
# ## Target Variable: `IsCanceled` and `ReservationStatus`

# %%
df['IsCanceled'].value_counts()
# Out:
# 0    63371
# 1    24025
# Name: IsCanceled, dtype: int64

# %%
df['ReservationStatus'].value_counts()
# Out:
# Check-Out    63371
# Canceled     23011
# No-Show       1014
# Name: ReservationStatus, dtype: int64

# %% [markdown]
# * `ReservationStatus` is essentially the same as `IsCanceled` since the Canceled and No-Show groups were combined into just canceled (1)
#
# * We will drop the 'ReservationStatus' column

# %% [markdown]
# ## `Hotel`

# %%
df['Hotel'].value_counts()
# Out:
# h2    53428
# h1    33968
# Name: Hotel, dtype: int64

# %% [markdown]
# * h1 is a resort hotel
# * h2 is a city hotel

# %% [markdown]
# ## `ArrivalDateYear`, `ArrivalDateMonth`, `ArrivalDateWeekNumber`, and `ArrivalDateDayOfMonth`

# %%
arrival_columns = ['ArrivalDateYear','ArrivalDateMonth', 'ArrivalDateWeekNumber', 'ArrivalDateDayOfMonth']

fig, axes = plt.subplots(ncols=2, nrows=2, figsize=(15,10))
i = 0
for col in arrival_columns:
    j = i%2
    ax = axes[i//2, j]
    ax.title.set_text(f"{col}")
    ax.tick_params(labelrotation=45)
    sns.countplot(data=df, x=col, ax=ax)
    i=i+1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# * Most of the bookings are from 2016
# * August and July have the most bookings
# * Weeks 30-36 have the most bookings (this lines up with July/August)
# * Nothing stands out too much for day of month, except the 31st has the least amount of bookings

# %% [markdown]
# ## `StaysInWeekendNights` and  `StaysInWeekNights`

# %%
fig, ax = plt.subplots(1,2, figsize=(20,7))

sns.countplot(data=df, x='StaysInWeekendNights', ax=ax[0])
sns.countplot(data=df, x='StaysInWeekNights', ax=ax[1])
plt.tight_layout()
plt.show()

# %%
df[['StaysInWeekendNights','StaysInWeekNights']].describe()
# Out:
#        StaysInWeekendNights  StaysInWeekNights
# count          87396.000000       87396.000000
# mean               1.005263           2.625395
# std                1.031921           2.053584
# min                0.000000           0.000000
# 25%                0.000000           1.000000
# 50%                1.000000           2.000000
# 75%                2.000000           4.000000
# max               19.000000          50.000000

# %% [markdown]
# # `Meals`

# %%
df['Meal'].value_counts()
# Out:
# BB           67978
# SC            9481
# HB            9085
# Undefined      492
# FB             360
# Name: Meal, dtype: int64

# %% [markdown]
# ## `MarketSegment` and `DistributionChannel`

# %%
df['MarketSegment'].value_counts()
# Out:
# Online TA        51618
# Offline TA/TO    13889
# Direct           11804
# Groups            4942
# Corporate         4212
# Complementary      702
# Aviation           227
# Undefined            2
# Name: MarketSegment, dtype: int64

# %%
df['DistributionChannel'].value_counts()
# Out:
# TA/TO        69141
# Direct       12988
# Corporate     5081
# GDS            181
# Undefined        5
# Name: DistributionChannel, dtype: int64

# %%
fig, ax = plt.subplots(1,2, figsize=(18,8))

sns.countplot(data=df, x='MarketSegment', ax=ax[0])
sns.countplot(data=df, x='DistributionChannel', ax=ax[1])
plt.tight_layout()
plt.show()

# %% [markdown]
# * `MarketSegment` and `DistributionChannel` seem to be similar, we might not need both of them
# * `MarketSegment` seems to be more about the customer type
# * `DistributionChannel` is how the booking was made
# *  Note: GDS (Global Distribution System) is a travel agent booking system

# %% [markdown]
# ## `IsRepeatedGuest`,  `PreviousCancellations`, and `PreviousBookingsNotCanceled`

# %%
df['IsRepeatedGuest'].value_counts(normalize=True)
# Out:
# 0    0.960925
# 1    0.039075
# Name: IsRepeatedGuest, dtype: float64

# %%
df['PreviousCancellations'].value_counts(normalize=True)
# Out:
# 0     0.980720
# 1     0.016099
# 2     0.001282
# 3     0.000698
# 4     0.000343
# 11    0.000309
# 5     0.000217
# 6     0.000195
# 13    0.000046
# 25    0.000023
# 24    0.000023
# 26    0.000011
# 14    0.000011
# 19    0.000011
# 21    0.000011
# Name: PreviousCancellations, dtype: float64

# %%
df['PreviousBookingsNotCanceled'].value_counts(normalize=True)
# Out:
# 0     0.959438
# 1     0.016957
# 2     0.006636
# 3     0.003787
# 4     0.002609
#         ...
# 47    0.000011
# 49    0.000011
# 50    0.000011
# 51    0.000011
# 72    0.000011
# Name: PreviousBookingsNotCanceled, Length: 73, dtype: float64

# %% [markdown]
# * 96% of the bookings are not a repeated guest
# * 98% of the bookings have had 0 previous cancellations
# * 96% of the bookings have had 0 previous bookings not canceled
# * It is unclear at the moment if these columns will be useful

# %% [markdown]
# ## `ReservedRoomType` and `AssignedRoomType`

# %%
print('Number of Reserved Room Types: ',df['ReservedRoomType'].nunique())
print('Number of Assigned Room Types: ',df['AssignedRoomType'].nunique())
# Out:
# Number of Reserved Room Types:  10
# Number of Assigned Room Types:  12

# %%
df['ReservedRoomType'].value_counts()
# Out:
# A                   56552
# D                   17398
# E                    6049
# F                    2823
# G                    2052
# B                     999
# C                     915
# H                     596
# L                       6
# P                       6
# Name: ReservedRoomType, dtype: int64

# %%
df['AssignedRoomType'].value_counts()
# Out:
# A                   46313
# D                   22432
# E                    7195
# F                    3627
# G                    2498
# C                    2165
# B                    1820
# H                     706
# I                     357
# K                     276
# P                       6
# L                       1
# Name: AssignedRoomType, dtype: int64

# %%
condition = df['ReservedRoomType'] == df['AssignedRoomType']
df['res_equals_assign'] = np.where(condition, 1, 0)

df[['ReservedRoomType','AssignedRoomType','res_equals_assign']].head()
# Out:
#    ReservedRoomType  AssignedRoomType  res_equals_assign
# 0  C                 C                                 1
# 1  C                 C                                 1
# 2  A                 C                                 0
# 3  A                 A                                 1
# 4  A                 A                                 1

# %% [markdown]
# * Room type 'K' and 'I' are not in the the `ReservedRoomType` column. There will clearly be some bookings where they did not get the same type of room that was reserved.
# * It could be useful to create a new column `res_equals_assign` which indicates if the reserved room equals the assigned room (1) or not (0)

# %% [markdown]
# ## `BookingChanges`

# %%
df['BookingChanges'].value_counts()
# Out:
# 0     71494
# 1     10902
# 2      3508
# 3       875
# 4       356
# 5       116
# 6        59
# 7        31
# 8        17
# 9         8
# 10        6
# 13        5
# 14        5
# 15        3
# 16        2
# 17        2
# 12        2
# 11        2
# 20        1
# 21        1
# 18        1
# Name: BookingChanges, dtype: int64

# %% [markdown]
# ## `DepositType`

# %%
df['DepositType'].value_counts()
# Out:
# No Deposit         86251
# Non Refund          1038
# Refundable           107
# Name: DepositType, dtype: int64

# %% [markdown]
# ## `Company` and `Agent`

# %%
df['Company'].value_counts(normalize=True)
# Out:
#        NULL    0.939826
#          40    0.009737
#         223    0.005755
#          45    0.002723
#         153    0.002357
#                  ...
#          96    0.000011
#          76    0.000011
#         184    0.000011
#          54    0.000011
#         402    0.000011
# Name: Company, Length: 353, dtype: float64

# %%
df['Agent'].value_counts(normalize=True)
# Out:
#           9    0.329065
#         240    0.149069
#        NULL    0.139514
#          14    0.038320
#           7    0.037759
#                  ...
#         257    0.000011
#         291    0.000011
#          93    0.000011
#         483    0.000011
#         449    0.000011
# Name: Agent, Length: 334, dtype: float64

# %%
pd.set_option('display.max_rows', 334)

df['Agent'].value_counts().to_frame()
# Out:
#              Agent
#           9  28759
#         240  13028
#        NULL  12193
#          14   3349
#           7   3300
#         250   2779
#         241   1644
#          28   1502
#           8   1383
#           1   1232
#           6   1117
#          40    986
#         314    844
#         242    722
#          83    614
#          85    524
#         243    477
#         171    402
#          27    395
#           3    363
#          22    345
#          11    318
#          15    303
#         196    281
#         177    277
#          96    272
#         138    257
#          37    225
#          16    220
#         229    218
#           5    216
#          10    214
#          21    199
#          42    194
#         115    192
#         156    187
#          26    187
#         175    182
#         195    181
#          86    180
#         273    179
#         251    175
#         134    168
#         143    163
#         298    160
#         152    156
# ...

# %% [markdown]
# * 94% of rows are NULL for `Company`, we will most likely drop this column
# * About 14% are NULL for `Agent`, we will keep this column for now
# * Might be be a good idea to recode column into groups by number of bookings i.e. less than 100, between 100 and 1000, greater than 1000 etc.

# %% [markdown]
# ## `DaysInWaitingList`

# %%
df['DaysInWaitingList'].value_counts(normalize=True)
# Out:
# 0      0.990160
# 63     0.000606
# 87     0.000286
# 44     0.000263
# 15     0.000252
# 58     0.000240
# 48     0.000240
# 122    0.000240
# 38     0.000217
# 77     0.000195
# 27     0.000195
# 34     0.000172
# 4      0.000172
# 147    0.000160
# 50     0.000160
# 98     0.000149
# 59     0.000149
# 101    0.000149
# 178    0.000137
# 31     0.000137
# 1      0.000137
# 56     0.000126
# 176    0.000126
# 17     0.000114
# 69     0.000114
# 99     0.000114
# 43     0.000114
# 25     0.000114
# 187    0.000114
# 60     0.000114
# 125    0.000114
# 223    0.000114
# 46     0.000103
# 39     0.000103
# 61     0.000103
# 14     0.000103
# 6      0.000103
# 259    0.000103
# 111    0.000092
# 49     0.000092
# 40     0.000092
# 96     0.000092
# 5      0.000092
# 108    0.000080
# 65     0.000080
# 236    0.000080
# 11     0.000080
# 28     0.000080
# 22     0.000080
# 35     0.000080
# 8      0.000080
# 20     0.000080
# 71     0.000080
# 68     0.000080
# 33     0.000080
# ...

# %% [markdown]
# ## `CustomerType`

# %%
df['CustomerType'].value_counts()
# Out:
# Transient          71986
# Transient-Party    11727
# Contract            3139
# Group                544
# Name: CustomerType, dtype: int64

# %% [markdown]
# ## `RequiredCarParkingSpaces` and `TotalOfSpecialRequests`

# %%
df['RequiredCarParkingSpaces'].value_counts()
# Out:
# 0    80083
# 1     7280
# 2       28
# 3        3
# 8        2
# Name: RequiredCarParkingSpaces, dtype: int64

# %%
df['TotalOfSpecialRequests'].value_counts()
# Out:
# 0    43894
# 1    29017
# 2    11812
# 3     2317
# 4      320
# 5       36
# Name: TotalOfSpecialRequests, dtype: int64

# %% [markdown]
# ## `LeadTime`

# %%
df['LeadTime'].describe()
# Out:
# count    87396.000000
# mean        79.891368
# std         86.052325
# min          0.000000
# 25%         11.000000
# 50%         49.000000
# 75%        125.000000
# max        737.000000
# Name: LeadTime, dtype: float64

# %%
sns.histplot(data=df, x='LeadTime')
plt.show()

# %% [markdown]
# ## `Adults`, `Children`, and `Babies`

# %%
# There are 385 bookings with 0 adults

df['Adults'].value_counts()
# Out:
# 2     64497
# 1     16503
# 3      5935
# 0       385
# 4        60
# 26        5
# 27        2
# 20        2
# 5         2
# 40        1
# 50        1
# 55        1
# 6         1
# 10        1
# Name: Adults, dtype: int64

# %%
# There are 219 bookings where there are 0 adults but at least 1 child
# It is unclear what age a 'child' is defined as, these could be teenagers, or it could be a mistake
# Note: All 219 come from h2, which is a city hotel
df.query('Adults == 0 and Children > 0')
# Out:
#       Hotel  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 34444    h2           0         1             2015           August
# 34502    h2           0       104             2015           August
# 34670    h2           0         3             2015           August
# 35032    h2           0        15             2015           August
# 36578    h2           1        48             2015          October
# 36946    h2           1         6             2015         December
# 36964    h2           0         6             2015         December
# 36997    h2           0         1             2015         December
# 37006    h2           1        12             2015         December
# 37029    h2           0         7             2015         December
# 37189    h2           0        30             2016          January
# 37230    h2           0        33             2016          January
# 37242    h2           0         0             2016          January
# ...

# %%
# There are 166 bookings with 0 adults and 0 children

df.query('Adults == 0 and Children == 0')
# Out:
#       Hotel  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 2088     h1           0         1             2015          October
# 2224     h1           0         0             2015          October
# 2804     h1           0        36             2015         November
# 3091     h1           0       165             2015         December
# 3099     h1           0       165             2015         December
# 3325     h1           1         0             2016         February
# 7039     h1           1         0             2016         November
# 26491    h1           0        31             2016         December
# 26726    h1           0         4             2017          January
# 27391    h1           0        46             2017          January
# 29113    h1           0        15             2017            March
# 31457    h1           0         1             2017             June
# 34135    h2           0       132             2015             July
# ...

# %%
# There are bookings with more than 20 adults, all of which were canceled. Also, the ADR is 0

df.query('Adults > 20')
# Out:
#      Hotel  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 1455    h1           1       304             2015        September
# 1503    h1           1       333             2015        September
# 1558    h1           1       336             2015        September
# 1664    h1           1       340             2015        September
# 1788    h1           1       347             2015        September
# 1816    h1           1       349             2015        September
# 1859    h1           1       352             2015        September
# 1897    h1           1       354             2015        September
# 2044    h1           1       361             2015          October
# 2053    h1           1       338             2015          October
#
#       ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 1455                     36                      3                     0
# 1503                     36                      5                     2
# ...

# %%
# There is 1 booking with 9 and 10 babies, this could be a mistake

df['Babies'].value_counts()
# Out:
# 0     86482
# 1       897
# 2        15
# 10        1
# 9         1
# Name: Babies, dtype: int64

# %%
df.query('Babies >= 9')
# Out:
#       Hotel  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 37297    h2           0        37             2016          January
# 54487    h2           0        11             2015          October
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 37297                      3                     12                     0
# 54487                     42                     11                     2
#
#        StaysInWeekNights  Adults  Children  Babies       Meal Country  \
# 37297                  2       2       0.0      10  BB            PRT
# 54487                  1       1       0.0       9  BB            GBR
#
#       MarketSegment DistributionChannel  IsRepeatedGuest  \
# 37297     Online TA               TA/TO                0
# 54487     Corporate           Corporate                0
#
#        PreviousCancellations  PreviousBookingsNotCanceled  ReservedRoomType  \
# 37297                      0                            0  D
# ...

# %%
# # There is also 1 booking with 10 children
df['Children'].value_counts()
# Out:
# 0.0     79032
# 1.0      4695
# 2.0      3593
# 3.0        75
# 10.0        1
# Name: Children, dtype: int64

# %%
df.query('Children == 10')
# Out:
#     Hotel  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 320    h1           1        55             2015             July
#
#      ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 320                     29                     12                     4
#
#      StaysInWeekNights  Adults  Children  Babies       Meal Country  \
# 320                 10       2      10.0       0  BB            PRT
#
#      MarketSegment DistributionChannel  IsRepeatedGuest  \
# 320  Offline TA/TO               TA/TO                0
#
#      PreviousCancellations  PreviousBookingsNotCanceled  ReservedRoomType  \
# 320                      0                            0  D
#
#      AssignedRoomType  BookingChanges      DepositType        Agent  \
# 320  D                              2  No Deposit                 8
#
#          Company  DaysInWaitingList CustomerType     ADR  \
# 320         NULL                  0     Contract  133.16
#
# ...

# %% [markdown]
# * There are 385 bookings with 0 adults
# * There are 219 bookings where there are 0 adults but at least 1 child
# * It is unclear what age a 'child' is defined as, these could be teenagers, or it could be a mistake
# * There is 1 booking with 10 babies, and 1 with 10 children

# %% [markdown]
# ## `ADR`

# %% [markdown]
# ### Negative ADR

# %%
# There is a booking with a negative ADR
df.query('ADR < 0')
# Out:
#       Hotel  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 11591    h1           0       195             2017            March
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 11591                     10                      5                     4
#
#        StaysInWeekNights  Adults  Children  Babies       Meal Country  \
# 11591                  6       2       0.0       0  BB            GBR
#
#       MarketSegment DistributionChannel  IsRepeatedGuest  \
# 11591        Groups              Direct                1
#
#        PreviousCancellations  PreviousBookingsNotCanceled  ReservedRoomType  \
# 11591                      0                            2  A
#
#        AssignedRoomType  BookingChanges      DepositType        Agent  \
# 11591  H                              2  No Deposit               273
#
#            Company  DaysInWaitingList     CustomerType   ADR  \
# 11591         NULL                  0  Transient-Party -6.38
#
# ...

# %%
# Taking a look at the ADR on similar bookings, we can replace that negative ADR with the mean here
ADR_neg_group = df.query('ReservationStatusDate == "2017-03-15" and StaysInWeekendNights == 4 and CustomerType == "Transient-Party" and ADR > 0')
ADR_neg_group.head()
# Out:
#       Hotel  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 28513    h1           0       201             2017            March
# 28514    h1           0       195             2017            March
# 28517    h1           0       195             2017            March
# 28519    h1           0       201             2017            March
# 28522    h1           0       195             2017            March
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 28513                     10                      5                     4
# 28514                     10                      5                     4
# 28517                     10                      5                     4
# 28519                     10                      5                     4
# 28522                     10                      5                     4
#
#        StaysInWeekNights  Adults  Children  Babies       Meal Country  \
# ...

# %%
df.loc[11591,'ADR'] = round(ADR_neg_group['ADR'].mean(),2)
df.loc[11591,'ADR']
# Out:
# 57.32

# %% [markdown]
# ### High ADR

# %%
# There is a booking with ADR of 5400
df.query('ADR == 5400')
# Out:
#       Hotel  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 38749    h2           1        35             2016            March
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 38749                     13                     25                     0
#
#        StaysInWeekNights  Adults  Children  Babies       Meal Country  \
# 38749                  1       2       0.0       0  BB            PRT
#
#        MarketSegment DistributionChannel  IsRepeatedGuest  \
# 38749  Offline TA/TO               TA/TO                0
#
#        PreviousCancellations  PreviousBookingsNotCanceled  ReservedRoomType  \
# 38749                      0                            0  A
#
#        AssignedRoomType  BookingChanges      DepositType        Agent  \
# 38749  A                              1  Non Refund                12
#
#            Company  DaysInWaitingList CustomerType     ADR  \
# 38749         NULL                  0    Transient  5400.0
#
# ...

# %%
ADR_high_group = df.query('ReservationStatusDate == "2016-02-19" and StaysInWeekNights == 1 and CustomerType == "Transient" and ADR < 5400 and Adults == 2')
ADR_high_group.head()
# Out:
#       Hotel  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 11034    h1           0         1             2016         February
# 16780    h1           0         7             2016         February
# 16782    h1           0         0             2016         February
# 16790    h1           0         1             2016         February
# 16794    h1           0         0             2016         February
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 11034                      8                     18                     0
# 16780                      8                     18                     0
# 16782                      8                     18                     0
# 16790                      8                     18                     0
# 16794                      8                     18                     0
#
#        StaysInWeekNights  Adults  Children  Babies       Meal Country  \
# ...

# %%
df.loc[38749,'ADR'] = round(ADR_high_group['ADR'].mean(),2)
df.loc[38749,'ADR']
# Out:
# 75.72

# %% [markdown]
# ### Zero ADR

# %%
# There are 1778 bookings with ADR of 0, 640 of those are Complimentary
ADR_zero = df.query('ADR == 0 and MarketSegment !="Complementary"')
ADR_zero.head()
# Out:
#     Hotel  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0      h1           0       342             2015             July
# 1      h1           0       737             2015             July
# 163    h1           0       111             2015             July
# 164    h1           0         0             2015             July
# 192    h1           0         8             2015             July
#
#      ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                       27                      1                     0
# 1                       27                      1                     0
# 163                     28                      6                     0
# 164                     28                      6                     0
# 192                     28                      7                     0
#
#      StaysInWeekNights  Adults  Children  Babies       Meal Country  \
# ...

# %%
df['ADR'].describe()
# Out:
# count    87396.000000
# mean       106.277054
# std         52.017095
# min          0.000000
# 25%         72.000000
# 50%         98.100000
# 75%        134.000000
# max        510.000000
# Name: ADR, dtype: float64

# %%
df['ADR'].median()
# Out:
# 98.1

# %%
df['ADR'].plot(kind='hist', bins=100 )

plt.axvline(98.1, c='r')
plt.text(35,5050,'Median',color='r')

plt.axvline(106.27,c='purple')
plt.text(120,5050,'Mean',color='purple')

plt.show()

# %% [markdown]
# * There is a booking with a negative ADR, we replaced it with the mean of the ADR from similar bookings
# * There is a booking with ADR of 5400, we replaced it in a similar way
# * There are 1778 bookings with ADR of 0, 640 of those are Complimentary. That leaves 1138 booking with an ADR of 0.
# * 1138 bookings with 0 ADR need to be dealt with still

# %% [markdown]
# ## `Country`

# %%
c = ['aqua','aquamarine','beige','bisque','blanchedalmond','blue',
         'blueviolet','brown','burlywood','cadetblue','chartreuse','chocolate','coral','cornflowerblue',
         'cornsilk','crimson','cyan','darkblue','darkcyan','darkgoldenrod','darkgray','darkgreen','darkgrey',
         'darkkhaki','darkmagenta','darkolivegreen']
 

plt.figure(figsize=(10,6))

ax = df['Country'].value_counts(ascending=False).head(20).plot(kind='bar', color = c)


ax.set_ylabel('Count')
ax.set_xlabel('Countries')
ax.set_title('Top 20 Countries of Origin for Bookings')
for p in ax.patches:
        width, height = p.get_width(), p.get_height()
        x, y = p.get_xy() 
        ax.text(x+width-0.2, 
                y+height,
                '{:.0f}'.format(height),
                weight='bold',
                horizontalalignment='center',
                size='small') 
                
plt.show()

# %%
# It may be a good idea to recode the countries as their cooresponding Region or Continent
# This will give us less groups (and less dummy variables when we get to that step)
country_tables = pd.read_html('https://statisticstimes.com/geography/countries-by-continents.php')
countries = country_tables[2][['Country or Area', 'ISO-alpha3 Code', 'Region 1', 'Continent']]
countries.head()
# Out:
#   Country or Area ISO-alpha3 Code         Region 1 Continent
# 0     Afghanistan             AFG    Southern Asia      Asia
# 1   Åland Islands             ALA  Northern Europe    Europe
# 2         Albania             ALB  Southern Europe    Europe
# 3         Algeria             DZA  Northern Africa    Africa
# 4  American Samoa             ASM        Polynesia   Oceania

# %%
country_continent = df['Country'].to_frame().merge(countries[['ISO-alpha3 Code','Continent']], how='left', left_on='Country', right_on='ISO-alpha3 Code')
country_continent.head()
# Out:
#   Country ISO-alpha3 Code Continent
# 0     PRT             PRT    Europe
# 1     PRT             PRT    Europe
# 2     GBR             GBR    Europe
# 3     GBR             GBR    Europe
# 4     GBR             GBR    Europe

# %%
df['Continent'] = country_continent['Continent']
df.head()
# Out:
#   Hotel  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0    h1           0       342             2015             July
# 1    h1           0       737             2015             July
# 2    h1           0         7             2015             July
# 3    h1           0        13             2015             July
# 4    h1           0        14             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 2                     27                      1                     0
# 3                     27                      1                     0
# 4                     27                      1                     0
#
#    StaysInWeekNights  Adults  Children  Babies       Meal Country  \
# 0                  0       2       0.0       0  BB            PRT
# ...

# %%
df['Continent'] = df['Continent'].fillna('unknown')

# %%
df['Continent'].value_counts()
# Out:
# Europe           77331
# Asia              2520
# South America     2447
# North America     2032
# unknown           1591
# Africa            1025
# Oceania            448
# Antarctica           2
# Name: Continent, dtype: int64

# %% [markdown]
# ## `ReservationStatusDate`

# %%
df['ReservationStatusDate'] = pd.to_datetime(df['ReservationStatusDate'])

# %% [markdown]
# # 7)  Columns to drop:
#
# * `ReservationStatus`: This is essentially the same as our target column, so we do not need both.
# * `DistributionChannel` : We observed a similarity with `MarketSegment`, so we will just use that column instead of both
# * `Company`: Most of the data is missing here, so we will not use this column.
# * `Country` : We created a new column for `Continent`, so we will not be using both
#
# Note: we may drop more columns later, but we will leave the rest for now

# %%
df.to_csv('data/full_data.csv')

# %% [markdown]
# ## Things that still need to be dealt with:
#
# 1) `PreviousCancellations` and `PreviousBookingsNotCanceled`: Which to keep? (if any)
#
# 2) `Agent`: There are 334 unique agents, but 14% is NULL.
#
# 3) 166 bookings with 0 adults and 0 children
#
# 4) 1138 bookings with 0 `ADR`
