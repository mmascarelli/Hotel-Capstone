# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('data/bbe.csv')
df.head(2)
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
#
#                                        title               series  \
# 0                           The Hunger Games  The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix      Harry Potter #5
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
#
#                                          description language           isbn  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English  9780439023481
# 1  There is a door at the end of a silent corrido...  English  9780439358071
#
#                                               genres  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
#
# ...

# %%
round(df.isna().sum()/len(df)*100,2)
# Out:
# bookId               0.00
# title                0.00
# series              55.28
# author               0.00
# rating               0.00
# description          2.55
# language             7.25
# isbn                 0.00
# genres               0.00
# characters           0.00
# bookFormat           2.81
# edition             90.56
# pages                4.47
# publisher            7.04
# publishDate          1.68
# firstPublishDate    40.64
# awards               0.00
# numRatings           0.00
# ratingsByStars       0.00
# likedPercent         1.19
# setting              0.00
# coverImg             1.15
# bbeScore             0.00
# bbeVotes             0.00
# price               27.37
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52478 entries, 0 to 52477
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   bookId            52478 non-null  object
#  1   title             52478 non-null  object
#  2   series            23470 non-null  object
#  3   author            52478 non-null  object
#  4   rating            52478 non-null  float64
#  5   description       51140 non-null  object
#  6   language          48672 non-null  object
#  7   isbn              52478 non-null  object
#  8   genres            52478 non-null  object
#  9   characters        52478 non-null  object
#  10  bookFormat        51005 non-null  object
#  11  edition           4955 non-null   object
#  12  pages             50131 non-null  object
#  13  publisher         48782 non-null  object
#  14  publishDate       51598 non-null  object
#  15  firstPublishDate  31152 non-null  object
# ...

# %%
df = df.dropna(axis=0, subset='price').reset_index(drop=True)

# %%
df[df.duplicated(subset=['title'])==True].sort_values(by='title')
# Out:
#                         bookId             title                    series  \
# 2977         5413._Salem_s_Lot      'Salem's Lot                       NaN
# 34663       16000978-til-death        'Til Death            Rebel Ridge #3
# 9310                 7104.1919              1919     The U.S.A. Trilogy #2
# 2331              6443834-1q84              1Q84                   1Q84 #1
# 3631              7717482-1q84              1Q84                   1Q84 #3
# ...                        ...               ...                       ...
# 28738          6388007-wounded           Wounded                       NaN
# 35525            362824.Wraith            Wraith         Zoë Martinique #1
# 30714  301826.You_Belong_to_Me  You Belong to Me     Cardinia's Royalty #2
# 5852             105760.Zodiac            Zodiac                       NaN
# 26983               13571757-1          アオハライド 1  アオハライド [Ao Haru Ride] #1
#
#                                                   author  rating  \
# ...

# %%
df.query('title == "\'Salem\'s Lot"')
# Out:
#                   bookId         title series  \
# 287   11590._Salem_s_Lot  'Salem's Lot    NaN
# 2977   5413._Salem_s_Lot  'Salem's Lot    NaN
#
#                                                  author  rating  \
# 287                     Stephen King (Goodreads Author)    4.03
# 2977  Stephen King (Goodreads Author), Jerry N. Uels...    4.25
#
#                                             description language  \
# 287   Thousands of miles away from the small townshi...  English
# 2977  Stephen King's second novel, the vampire bests...  English
#
#                isbn                                             genres  \
# 287   9780450031069  ['Horror', 'Fiction', 'Vampires', 'Fantasy', '...
# 2977  9780385516488  ['Horror', 'Fiction', 'Vampires', 'Fantasy', '...
#
#                                              characters bookFormat  \
# 287   ['Benjamin Mears', 'Susan Norton', 'Matt Burke...  Paperback
# 2977                                                 []  Hardcover
#
# ...

# %%
df2.reset_index(drop=True, inplace=True)

# %%
def fix_dots(a):
    t = a.split('.')
    if len(t)>1:
        return t[0]+'.'+''.join(t[1:])
    else:
        return t[0]
    

prices = []    
for price in df2['price']:
    fix = fix_dots(price)
    prices.append(fix)

# %%
floats = [float(x) for x in prices]
floats
